# %%
import pandas as pd
df_actor = pd.read_csv('./data/actor.csv')

# %%
# TABLA ACTOR

# %%
df_actor = df_actor.loc[:,~df_actor.columns.duplicated(keep='first')]

df_actor.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2         3         ED         CHASE  2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33

# %%
df_actor.drop('last_update', axis=1, inplace=True)

# %%
df_actor.shape
# Out:
# (200, 3)

# %%
df_actor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   actor_id    200 non-null    int64
#  1   first_name  200 non-null    object
#  2   last_name   200 non-null    object
#  3   full_name   200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
df_actor.head()
# Out:
#    actor_id first_name     last_name
# 0         1   PENELOPE       GUINESS
# 1         2       NICK      WAHLBERG
# 2         3         ED         CHASE
# 3         4   JENNIFER         DAVIS
# 4         5     JOHNNY  LOLLOBRIGIDA

# %%
df_actor["full_name"] = df_actor["first_name"] + " " + df_actor["last_name"]

# %%
df_actor.head()
# Out:
#    actor_id first_name     last_name            full_name
# 0         1   PENELOPE       GUINESS     PENELOPE GUINESS
# 1         2       NICK      WAHLBERG        NICK WAHLBERG
# 2         3         ED         CHASE             ED CHASE
# 3         4   JENNIFER         DAVIS       JENNIFER DAVIS
# 4         5     JOHNNY  LOLLOBRIGIDA  JOHNNY LOLLOBRIGIDA

# %%
df_actor
# Out:
#      actor_id first_name     last_name            full_name
# 0           1   PENELOPE       GUINESS     PENELOPE GUINESS
# 1           2       NICK      WAHLBERG        NICK WAHLBERG
# 2           3         ED         CHASE             ED CHASE
# 3           4   JENNIFER         DAVIS       JENNIFER DAVIS
# 4           5     JOHNNY  LOLLOBRIGIDA  JOHNNY LOLLOBRIGIDA
# ..        ...        ...           ...                  ...
# 195       196       BELA        WALKEN          BELA WALKEN
# 196       197      REESE          WEST           REESE WEST
# 197       198       MARY        KEITEL          MARY KEITEL
# 198       199      JULIA       FAWCETT        JULIA FAWCETT
# 199       200      THORA        TEMPLE         THORA TEMPLE
#
# [200 rows x 4 columns]

# %%
# TABLA CATEGORY

# %%
df_category = pd.read_csv('./data/category.csv')

# %%
df_category = df_category.loc[:,~df_category.columns.duplicated(keep='first')]
df_category.head()
# Out:
#    category_id       name          last_update
# 0            1     Action  2006-02-15 04:46:27
# 1            2  Animation  2006-02-15 04:46:27
# 2            3   Children  2006-02-15 04:46:27
# 3            4   Classics  2006-02-15 04:46:27
# 4            5     Comedy  2006-02-15 04:46:27

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    16 non-null     int64
#  1   category_name  16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %%
df_category.drop('last_update', axis=1, inplace=True)

# %%
df_category = df_category.rename(columns={'name': 'category_name'})

# %%
df_category.head()
# Out:
#    category_id category_name
# 0            1        Action
# 1            2     Animation
# 2            3      Children
# 3            4      Classics
# 4            5        Comedy

# %%
# TABLA FILM

# %%
df_film = pd.read_csv('./data/film.csv')

# %%
df_film = df_film.loc[:,~df_film.columns.duplicated(keep='first')]

# %%
df_film.drop(['last_update', 'language_id', 'original_language_id'], axis=1, inplace=True)

# %%
df_film.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    rental_duration  rental_rate  length  replacement_cost rating  \
# 0                6         0.99      86             20.99     PG
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# 4                6         2.99     130             22.99      G
#
#                    special_features
# 0  Deleted Scenes,Behind the Scenes
# 1           Trailers,Deleted Scenes
# 2           Trailers,Deleted Scenes
# 3    Commentaries,Behind the Scenes
# 4                    Deleted Scenes

# %%
df_film.rename(columns={"film_id": "title_id"}, inplace=True)
df_film.head()
# Out:
#    title_id             title  \
# 0         1  ACADEMY DINOSAUR
# 1         2    ACE GOLDFINGER
# 2         3  ADAPTATION HOLES
# 3         4  AFFAIR PREJUDICE
# 4         5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    rental_duration  rental_rate  length  replacement_cost rating  \
# 0                6         0.99      86             20.99     PG
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# 4                6         2.99     130             22.99      G
#
#                    special_features
# 0  Deleted Scenes,Behind the Scenes
# 1           Trailers,Deleted Scenes
# 2           Trailers,Deleted Scenes
# 3    Commentaries,Behind the Scenes
# 4                    Deleted Scenes

# %%
df_film.shape
# Out:
# (1000, 10)

# %%
df_film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_id          1000 non-null   int64
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   length            1000 non-null   int64
#  4   replacement_cost  1000 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 39.2+ KB

# %%
df_film.drop("original_language_id", axis=1, inplace=True)

# borro esta columna porque está llena de valores nulos

# %%
df_film.head()
# Out:
#    title_id             title  \
# 0         1  ACADEMY DINOSAUR
# 1         2    ACE GOLDFINGER
# 2         3  ADAPTATION HOLES
# 3         4  AFFAIR PREJUDICE
# 4         5       AFRICAN EGG
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    rental_duration  rental_rate  length  replacement_cost rating  \
# 0                6         0.99      86             20.99     PG
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# 4                6         2.99     130             22.99      G
#
#                    special_features
# 0  Deleted Scenes,Behind the Scenes
# 1           Trailers,Deleted Scenes
# 2           Trailers,Deleted Scenes
# 3    Commentaries,Behind the Scenes
# 4                    Deleted Scenes

# %%
print(df_film['title'])
# Out:
# 0       ACADEMY DINOSAUR
# 1         ACE GOLDFINGER
# 2       ADAPTATION HOLES
# 3       AFFAIR PREJUDICE
# 4            AFRICAN EGG
#              ...
# 995       YOUNG LANGUAGE
# 996           YOUTH KICK
# 997         ZHIVAGO CORE
# 998    ZOOLANDER FICTION
# 999            ZORRO ARK
# Name: title, Length: 1000, dtype: object

# %%
df_film.drop(['rental_duration','rental_rate','rating','special_features'], axis=1, inplace=True)

# %%
df_film
# Out:
#      title_id              title  \
# 0           1   ACADEMY DINOSAUR
# 1           2     ACE GOLDFINGER
# 2           3   ADAPTATION HOLES
# 3           4   AFFAIR PREJUDICE
# 4           5        AFRICAN EGG
# ..        ...                ...
# 995       996     YOUNG LANGUAGE
# 996       997         YOUTH KICK
# 997       998       ZHIVAGO CORE
# 998       999  ZOOLANDER FICTION
# 999      1000          ZORRO ARK
#
#                                            description  length  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...      86
# 1    A Astounding Epistle of a Database Administrat...      48
# 2    A Astounding Reflection of a Lumberjack And a ...      50
# 3    A Fanciful Documentary of a Frisbee And a Lumb...     117
# 4    A Fast-Paced Documentary of a Pastry Chef And ...     130
# ..                                                 ...     ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...     183
# 996  A Touching Drama of a Teacher And a Cat who mu...     179
# 997  A Fateful Yarn of a Composer And a Man who mus...     105
# 998  A Fateful Reflection of a Waitress And a Boat ...     101
# 999  A Intrepid Panorama of a Mad Scientist And a B...      50
#
#      replacement_cost
# 0               20.99
# 1               12.99
# 2               18.99
# 3               26.99
# 4               22.99
# ..                ...
# 995              9.99
# 996             14.99
# 997             10.99
# 998             28.99
# 999             18.99
#
# [1000 rows x 5 columns]

# %%
df_film['actors'] = '' #creamos columna vacía
def actors(pelicula): #creamos función que saque los actores de esa peli
    act = []
    for i in df_old.index:
        if df_old.title[i] == pelicula:
            name = df_old.name_surname[i]
            act.append(name)
    return ', '.join(act)

# %%
df_film
# Out:
#      title_id                   title  \
# 0           1        ACADEMY DINOSAUR
# 1           2          ACE GOLDFINGER
# 2           3        ADAPTATION HOLES
# 3           4        AFFAIR PREJUDICE
# 4           5             AFRICAN EGG
# ..        ...                     ...
# 218       219            DEEP CRUSADE
# 219       220          DEER VIRGINIAN
# 220       221  DELIVERANCE MULHOLLAND
# 221       222         DESERT POSEIDON
# 222       223            DESIRE ALIEN
#
#                                            description  length  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...      86
# 1    A Astounding Epistle of a Database Administrat...      48
# 2    A Astounding Reflection of a Lumberjack And a ...      50
# 3    A Fanciful Documentary of a Frisbee And a Lumb...     117
# 4    A Fast-Paced Documentary of a Pastry Chef And ...     130
# ..                                                 ...     ...
# 218  A Amazing Tale of a Crocodile And a Squirrel w...      51
# 219  A Thoughtful Story of a Mad Cow And a Womanize...     106
# 220  A Astounding Saga of a Monkey And a Moose who ...     100
# 221  A Brilliant Documentary of a Butler And a Fris...      64
# 222  A Fast-Paced Tale of a Dog And a Forensic Psyc...      76
#
#      replacement_cost actors
# 0               20.99
# 1               12.99
# 2               18.99
# 3               26.99
# 4               22.99
# ..                ...    ...
# 218             20.99
# 219             13.99
# 220              9.99
# 221             27.99
# 222             24.99
#
# [223 rows x 6 columns]

# %%
#los introducimos por cada fila
for i in df_film.index:
    df_film['actors'][i] = actors(df_film.title[i])
# Out:
# /var/folders/75/q598wy0x5rq2j183ndtczjlm0000gn/T/ipykernel_52049/1893234069.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['actors'][i] = actors(df_film.title[i])

# %%
df_film
# Out:
#      title_id                   title  \
# 0           1        ACADEMY DINOSAUR
# 1           2          ACE GOLDFINGER
# 2           3        ADAPTATION HOLES
# 3           4        AFFAIR PREJUDICE
# 4           5             AFRICAN EGG
# ..        ...                     ...
# 218       219            DEEP CRUSADE
# 219       220          DEER VIRGINIAN
# 220       221  DELIVERANCE MULHOLLAND
# 221       222         DESERT POSEIDON
# 222       223            DESIRE ALIEN
#
#                                            description  length  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...      86
# 1    A Astounding Epistle of a Database Administrat...      48
# 2    A Astounding Reflection of a Lumberjack And a ...      50
# 3    A Fanciful Documentary of a Frisbee And a Lumb...     117
# 4    A Fast-Paced Documentary of a Pastry Chef And ...     130
# ..                                                 ...     ...
# 218  A Amazing Tale of a Crocodile And a Squirrel w...      51
# 219  A Thoughtful Story of a Mad Cow And a Womanize...     106
# 220  A Astounding Saga of a Monkey And a Moose who ...     100
# 221  A Brilliant Documentary of a Butler And a Fris...      64
# 222  A Fast-Paced Tale of a Dog And a Forensic Psyc...      76
#
#      replacement_cost                                             actors
# 0               20.99  PENELOPE GUINESS, CHRISTIAN GABLE, LUCILLE TRA...
# 1               12.99                                        BOB FAWCETT
# 2               18.99         NICK WAHLBERG, BOB FAWCETT, CAMERON STREEP
# 3               26.99
# 4               22.99
# ..                ...                                                ...
# 218             20.99                                        TIM HACKMAN
# 219             13.99
# 220              9.99                                       FRED COSTNER
# 221             27.99                                       GOLDIE BRODY
# 222             24.99                                       TOM MCKELLEN
#
# [223 rows x 6 columns]

# %%
# Relleno los elementos vacíos con valores nulos, para luego convertirlos en "unknown actors"
import numpy as np

df_film['actors'] = df_film['actors'].replace('', np.nan)
df_film['actors'] = df_film['actors'].fillna('unknown actors')

# %%
df_film
# Out:
#      title_id                   title  \
# 0           1        ACADEMY DINOSAUR
# 1           2          ACE GOLDFINGER
# 2           3        ADAPTATION HOLES
# 3           4        AFFAIR PREJUDICE
# 4           5             AFRICAN EGG
# ..        ...                     ...
# 218       219            DEEP CRUSADE
# 219       220          DEER VIRGINIAN
# 220       221  DELIVERANCE MULHOLLAND
# 221       222         DESERT POSEIDON
# 222       223            DESIRE ALIEN
#
#                                            description  length  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...      86
# 1    A Astounding Epistle of a Database Administrat...      48
# 2    A Astounding Reflection of a Lumberjack And a ...      50
# 3    A Fanciful Documentary of a Frisbee And a Lumb...     117
# 4    A Fast-Paced Documentary of a Pastry Chef And ...     130
# ..                                                 ...     ...
# 218  A Amazing Tale of a Crocodile And a Squirrel w...      51
# 219  A Thoughtful Story of a Mad Cow And a Womanize...     106
# 220  A Astounding Saga of a Monkey And a Moose who ...     100
# 221  A Brilliant Documentary of a Butler And a Fris...      64
# 222  A Fast-Paced Tale of a Dog And a Forensic Psyc...      76
#
#      replacement_cost                                             actors
# 0               20.99  PENELOPE GUINESS, CHRISTIAN GABLE, LUCILLE TRA...
# 1               12.99                                        BOB FAWCETT
# 2               18.99         NICK WAHLBERG, BOB FAWCETT, CAMERON STREEP
# 3               26.99                                     unknown actors
# 4               22.99                                     unknown actors
# ..                ...                                                ...
# 218             20.99                                        TIM HACKMAN
# 219             13.99                                     unknown actors
# 220              9.99                                       FRED COSTNER
# 221             27.99                                       GOLDIE BRODY
# 222             24.99                                       TOM MCKELLEN
#
# [223 rows x 6 columns]

# %%
df_film = df_film.rename(columns={'description': 'description_', 'length': 'length_'})

# %%
# TABLA INVENTORY

# %%
df_inventory = pd.read_csv('./data/inventory.csv')

# %%
df_inventory = df_inventory.loc[:,~df_inventory.columns.duplicated(keep='first')]
df_inventory.head()
# Out:
#    inventory_id  film_id  store_id          last_update
# 0             1        1         1  2006-02-15 05:09:17
# 1             2        1         1  2006-02-15 05:09:17
# 2             3        1         1  2006-02-15 05:09:17
# 3             4        1         1  2006-02-15 05:09:17
# 4             5        1         2  2006-02-15 05:09:17

# %%
df_inventory.drop('last_update', axis=1, inplace=True)

# %%
df_inventory.drop('store_id', axis=1, inplace=True)

# %%
df_inventory
# Out:
#      inventory_id  film_id
# 0               1        1
# 1               2        1
# 2               3        1
# 3               4        1
# 4               5        1
# ..            ...      ...
# 995           996      222
# 996           997      222
# 997           998      222
# 998           999      223
# 999          1000      223
#
# [1000 rows x 2 columns]

# %%
df_inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
# dtypes: int64(2)
# memory usage: 15.8 KB

# %%
df_inventory.rename(columns={"film_id": "title_id"}, inplace=True)

# %%
df_inventory
# Out:
#      inventory_id  title_id
# 0               1         1
# 1               2         1
# 2               3         1
# 3               4         1
# 4               5         1
# ..            ...       ...
# 995           996       222
# 996           997       222
# 997           998       222
# 998           999       223
# 999          1000       223
#
# [1000 rows x 2 columns]

# %%
# ¿Por qué en df_films de repente se redujeron el nº de filas a 223?

# Ahora hago el corte de todos los titulos de peliculas que me faltan en mi inventario. 

# Para eso, elimino de mi tabla de peliculas las filas de la 223 a la 1000. De esta manera, sólo tendré información de las películas de las que dispongo en mi inventario.


df_film = df_film.drop(df_film.index[223:], axis=0)

df_film.shape
# Out:
# (223, 5)

# %%
# TABLA LANGUAGE

# %%
df_language = pd.read_csv('./data/language.csv')
df_language = df_language.loc[:,~df_language.columns.duplicated(keep='first')]

# %%
df_language.drop('last_update', axis=1, inplace=True)

# %%
df_language.head()

# %%
# TABLA OLD HDD

# %%
df_old = pd.read_csv('./data/old_HDD.csv')
df_old = df_old.loc[:,~df_old.columns.duplicated(keep='first')]
df_old.head(100)
# Out:
#    first_name     last_name                  title  release_year  category_id
# 0    PENELOPE       GUINESS       ACADEMY DINOSAUR          2006            6
# 1    PENELOPE       GUINESS   ANACONDA CONFESSIONS          2006            2
# 2    PENELOPE       GUINESS            ANGELS LIFE          2006           13
# 3    PENELOPE       GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4    PENELOPE       GUINESS          CHEAPER CLYDE          2006           14
# ..        ...           ...                    ...           ...          ...
# 95     JOHNNY  LOLLOBRIGIDA        DAISY MENAGERIE          2006           14
# 96     JOHNNY  LOLLOBRIGIDA          ENOUGH RAGING          2006           16
# 97     JOHNNY  LOLLOBRIGIDA      ESCAPE METROPOLIS          2006           16
# 98     JOHNNY  LOLLOBRIGIDA            FIRE WOLVES          2006           10
# 99     JOHNNY  LOLLOBRIGIDA         FRONTIER CABIN          2006           13
#
# [100 rows x 5 columns]

# %%
df_old= df_old.loc[:,~df_old.columns.duplicated(keep='first')]

# %%
df_old['name_surname'] = pd.concat([df_old['first_name'], df_old['last_name']], axis=1).apply(lambda x: ' '.join(x), axis=1)

# %%
df_old.drop(['first_name', 'last_name'], axis=1, inplace=True)

# %%
df_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   release_year  1000 non-null   int64
#  2   category_id   1000 non-null   int64
#  3   name_surname  1000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 31.4+ KB

# %%
df_old.head()
# Out:
#                    title  release_year  category_id      name_surname
# 0       ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS
# 1   ANACONDA CONFESSIONS          2006            2  PENELOPE GUINESS
# 2            ANGELS LIFE          2006           13  PENELOPE GUINESS
# 3  BULWORTH COMMANDMENTS          2006           10  PENELOPE GUINESS
# 4          CHEAPER CLYDE          2006           14  PENELOPE GUINESS

# %%
name_surname = df_old.pop('name_surname')

df_old.insert(0, 'name_surname', name_surname) # Insertar la columna en la primera posición

df_old.head()
# Out:
#        name_surname                  title  release_year  category_id
# 0  PENELOPE GUINESS       ACADEMY DINOSAUR          2006            6
# 1  PENELOPE GUINESS   ANACONDA CONFESSIONS          2006            2
# 2  PENELOPE GUINESS            ANGELS LIFE          2006           13
# 3  PENELOPE GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4  PENELOPE GUINESS          CHEAPER CLYDE          2006           14

# %%
name_surname_list = df_old['name_surname'].tolist()

print(name_surname_list)
# Out:
# ['PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'PENELOPE GUINESS', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'NICK WAHLBERG', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'ED CHASE', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JENNIFER DAVIS', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'JOHNNY LOLLOBRIGIDA', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'BETTE NICHOLSON', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'GRACE MOSTEL', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'MATTHEW JOHANSSON', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'JOE SWANK', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABLE', 'CHRISTIAN GABL ...

# %%
# TABLA RENTAL

# %%
df_rental = pd.read_csv('./data/rental.csv')

# %%
df_rental = df_rental.loc[:,~df_rental.columns.duplicated(keep='first')]

# %%
df_rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date  staff_id          last_update
# 0  2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33         1  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39         1  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41         2  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21         1  2006-02-15 21:30:53

# %%
df_rental.drop(['staff_id','last_update'], axis=1, inplace=True)

# %%
df_rental.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date
# 0  2005-05-26 22:04:30
# 1  2005-05-28 19:40:33
# 2  2005-06-01 22:12:39
# 3  2005-06-03 01:43:41
# 4  2005-06-02 04:33:21

# %%
# Si nos fijamos en el value counts de la columna film_id de films vemos lo siguiente Vemos que la cantidad real de títulos son unos 223, sin embargo

# %%
# TABLA NUEVA LLAMADA CLIENTES

# %%
df_clients = pd.DataFrame(columns=['customer_id', 'name', 'address', 'phone'])

print(df_clients)
# Out:
# Empty DataFrame
# Columns: [customer_id, name, address, phone]
# Index: []

# %%
df_clients.loc[0] = ['1', 'Paco Perez', 'Calle Pez 32', '956189554']

# %%
print(df_clients)
# Out:
#   customer_id        name       address      phone
# 0           1  Paco Perez  Calle Pez 32  956189554

# %%
# AHORA EXPORTO LOS CSV LIMPIOS.

# %%
df_actor.to_csv("actores_limpio.csv", index=False)

# %%
df_category.to_csv("category_limpio.csv", index=False)
df_film.to_csv("film_limpio.csv", index=False)
df_inventory.to_csv("inventory_limpio.csv", index=False)
df_old.to_csv("old_limpio.csv", index=False)
df_rental.to_csv("rental_limpio.csv", index=False)

# %%
df_category.to_csv("category_limpio.csv", index=False)
df_film.to_csv("film_limpio2.csv", index=False)
df_inventory.to_csv("inventory_limpio2.csv", index=False)
df_old.to_csv("old_limpio.csv", index=False)
df_rental.to_csv("rental_limpio2.csv", index=False)

# %%
df_clients.to_csv("clients_limpisimo.csv", index=False)

# %%
df_film
# Out:
#      title_id                   title  \
# 0           1        ACADEMY DINOSAUR
# 1           2          ACE GOLDFINGER
# 2           3        ADAPTATION HOLES
# 3           4        AFFAIR PREJUDICE
# 4           5             AFRICAN EGG
# ..        ...                     ...
# 218       219            DEEP CRUSADE
# 219       220          DEER VIRGINIAN
# 220       221  DELIVERANCE MULHOLLAND
# 221       222         DESERT POSEIDON
# 222       223            DESIRE ALIEN
#
#                                            description  length  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...      86
# 1    A Astounding Epistle of a Database Administrat...      48
# 2    A Astounding Reflection of a Lumberjack And a ...      50
# 3    A Fanciful Documentary of a Frisbee And a Lumb...     117
# 4    A Fast-Paced Documentary of a Pastry Chef And ...     130
# ..                                                 ...     ...
# 218  A Amazing Tale of a Crocodile And a Squirrel w...      51
# 219  A Thoughtful Story of a Mad Cow And a Womanize...     106
# 220  A Astounding Saga of a Monkey And a Moose who ...     100
# 221  A Brilliant Documentary of a Butler And a Fris...      64
# 222  A Fast-Paced Tale of a Dog And a Forensic Psyc...      76
#
#      replacement_cost                                             actors
# 0               20.99  PENELOPE GUINESS, CHRISTIAN GABLE, LUCILLE TRA...
# 1               12.99                                        BOB FAWCETT
# 2               18.99         NICK WAHLBERG, BOB FAWCETT, CAMERON STREEP
# 3               26.99                                     unknown actors
# 4               22.99                                     unknown actors
# ..                ...                                                ...
# 218             20.99                                        TIM HACKMAN
# 219             13.99                                     unknown actors
# 220              9.99                                       FRED COSTNER
# 221             27.99                                       GOLDIE BRODY
# 222             24.99                                       TOM MCKELLEN
#
# [223 rows x 6 columns]

# %%
df_inventory
# Out:
#      inventory_id  title_id
# 0               1         1
# 1               2         1
# 2               3         1
# 3               4         1
# 4               5         1
# ..            ...       ...
# 995           996       222
# 996           997       222
# 997           998       222
# 998           999       223
# 999          1000       223
#
# [1000 rows x 2 columns]

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date
# 0    2005-05-26 22:04:30
# 1    2005-05-28 19:40:33
# 2    2005-06-01 22:12:39
# 3    2005-06-03 01:43:41
# 4    2005-06-02 04:33:21
# ..                   ...
# 995  2005-06-02 00:17:25
# 996  2005-06-01 22:41:57
# 997  2005-06-03 06:05:10
# 998  2005-06-08 19:42:56
# 999  2005-06-06 06:14:31
#
# [1000 rows x 5 columns]

# %%
import pandas as pd


# generar una lista de números del 1 al 1000
números = list(range(1, 1001))

# asignar la lista a la columna "customer_id"
df_rental['customer_id'] = números

# guardar el DataFrame actualizado en un archivo csv
df_rental.to_csv('rental_actualizadisimo.csv', index=False)

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367            1
# 1            2  2005-05-24 22:54:33          1525            2
# 2            3  2005-05-24 23:03:39          1711            3
# 3            4  2005-05-24 23:04:41          2452            4
# 4            5  2005-05-24 23:05:21          2079            5
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          996
# 996        998  2005-05-31 00:16:57          3395          997
# 997        999  2005-05-31 00:25:10          4433          998
# 998       1000  2005-05-31 00:25:56          1774          999
# 999       1001  2005-05-31 00:46:31          1498         1000
#
#              return_date
# 0    2005-05-26 22:04:30
# 1    2005-05-28 19:40:33
# 2    2005-06-01 22:12:39
# 3    2005-06-03 01:43:41
# 4    2005-06-02 04:33:21
# ..                   ...
# 995  2005-06-02 00:17:25
# 996  2005-06-01 22:41:57
# 997  2005-06-03 06:05:10
# 998  2005-06-08 19:42:56
# 999  2005-06-06 06:14:31
#
# [1000 rows x 5 columns]

# %%
df_clients
# Out:
#   customer_id        name       address      phone
# 0           1  Paco Perez  Calle Pez 32  956189554

# %%
df_list = [df_clients] * 1000

# %%
df_clients_1000 = pd.concat(df_list, ignore_index=True)

# %%
df_clients
# Out:
#   customer_id        name       address      phone
# 0           1  Paco Perez  Calle Pez 32  956189554

# %%
df_clients_mil = pd.concat([df_clients]*1000, ignore_index=True)

# %%
df_clients_mil
# Out:
#      customer_id        name       address      phone
# 0              1  Paco Perez  Calle Pez 32  956189554
# 1              1  Paco Perez  Calle Pez 32  956189554
# 2              1  Paco Perez  Calle Pez 32  956189554
# 3              1  Paco Perez  Calle Pez 32  956189554
# 4              1  Paco Perez  Calle Pez 32  956189554
# ..           ...         ...           ...        ...
# 995            1  Paco Perez  Calle Pez 32  956189554
# 996            1  Paco Perez  Calle Pez 32  956189554
# 997            1  Paco Perez  Calle Pez 32  956189554
# 998            1  Paco Perez  Calle Pez 32  956189554
# 999            1  Paco Perez  Calle Pez 32  956189554
#
# [1000 rows x 4 columns]

# %%
df_rental
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367            1
# 1            2  2005-05-24 22:54:33          1525            2
# 2            3  2005-05-24 23:03:39          1711            3
# 3            4  2005-05-24 23:04:41          2452            4
# 4            5  2005-05-24 23:05:21          2079            5
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          996
# 996        998  2005-05-31 00:16:57          3395          997
# 997        999  2005-05-31 00:25:10          4433          998
# 998       1000  2005-05-31 00:25:56          1774          999
# 999       1001  2005-05-31 00:46:31          1498         1000
#
#              return_date
# 0    2005-05-26 22:04:30
# 1    2005-05-28 19:40:33
# 2    2005-06-01 22:12:39
# 3    2005-06-03 01:43:41
# 4    2005-06-02 04:33:21
# ..                   ...
# 995  2005-06-02 00:17:25
# 996  2005-06-01 22:41:57
# 997  2005-06-03 06:05:10
# 998  2005-06-08 19:42:56
# 999  2005-06-06 06:14:31
#
# [1000 rows x 5 columns]

# %%
df_clients_mil = pd.concat([df_clients]*1000, ignore_index=True)

# %%
df_clients_mil
# Out:
#      customer_id        name       address      phone
# 0              1  Paco Perez  Calle Pez 32  956189554
# 1              1  Paco Perez  Calle Pez 32  956189554
# 2              1  Paco Perez  Calle Pez 32  956189554
# 3              1  Paco Perez  Calle Pez 32  956189554
# 4              1  Paco Perez  Calle Pez 32  956189554
# ..           ...         ...           ...        ...
# 995            1  Paco Perez  Calle Pez 32  956189554
# 996            1  Paco Perez  Calle Pez 32  956189554
# 997            1  Paco Perez  Calle Pez 32  956189554
# 998            1  Paco Perez  Calle Pez 32  956189554
# 999            1  Paco Perez  Calle Pez 32  956189554
#
# [1000 rows x 4 columns]

# %%
# Generar lista de números del 1 al 1000
new_customer_ids = list(range(1, 1001))

# Asignar la lista a la columna "customer_id"
df_clients_mil['customer_id'] = new_customer_ids

# %%
df_clients_mil
# Out:
#      customer_id        name       address      phone
# 0              1  Paco Perez  Calle Pez 32  956189554
# 1              2  Paco Perez  Calle Pez 32  956189554
# 2              3  Paco Perez  Calle Pez 32  956189554
# 3              4  Paco Perez  Calle Pez 32  956189554
# 4              5  Paco Perez  Calle Pez 32  956189554
# ..           ...         ...           ...        ...
# 995          996  Paco Perez  Calle Pez 32  956189554
# 996          997  Paco Perez  Calle Pez 32  956189554
# 997          998  Paco Perez  Calle Pez 32  956189554
# 998          999  Paco Perez  Calle Pez 32  956189554
# 999         1000  Paco Perez  Calle Pez 32  956189554
#
# [1000 rows x 4 columns]

# %%
df_clients_mil.to_csv("clients_mil.csv", index=False)
