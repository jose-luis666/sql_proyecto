# %% [markdown]
# # **PROYECTO SHARKS**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/attacks.csv', encoding='latin-1')

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df._get_numeric_data().shape  #con esto saco el shape de los elementos numéricos
# Out:
# (25723, 2)

# %%
df.select_dtypes('object').shape  # con esto saco el shape de los elementos tipo object
# Out:
# (25723, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# # **La mayoría de columnas del DF albergan datos de tipo object, frente a 2 columnas de tipo Float**

# %% [markdown]
# # Ahora voy a borrar valores nulos

# %%
umbral = 0.6  # Define el umbral del 60% de valores nulos
porcentaje_nulos = df.apply(lambda row: row.isnull().sum() / len(row), axis=1)  # Calcula el porcentaje de valores nulos en cada fila
num_filas = sum(porcentaje_nulos > umbral)  # Cuenta el número de filas que tienen un porcentaje de valores nulos mayor que el umbral

num_filas
# Out:
# 19421

# %%
# Ahora voy a borrar estas filas porque tienen demasiados valores nulos utilizando drop.

indices = porcentaje_nulos[porcentaje_nulos > umbral].index  # Obtiene los índices de las filas que cumplen el umbral
df = df.drop(indices, axis=0)  # Elimina las filas que cumplen el umbral del DataFrame

# %%
df.shape
# Out:
# (6302, 24)

# %%
# Ahora tengo muchas menos filas, genial

# %% [markdown]
# # **Filas duplicadas**

# %%
duplicados = df[df.duplicated()]

duplicados
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Esto significa que no hay filas duplicadas, genial

# %% [markdown]
# # **Ahora voy a ir columna por columna limpiando los datos**

# %% [markdown]
# **COLUMNA 1 - Case Number**

# %%
# Columna 1 : Case Number. Entiendo que es una especie de identificador, un ID.

df['Case Number'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 6297    <class 'str'>
# 6298    <class 'str'>
# 6299    <class 'str'>
# 6300    <class 'str'>
# 6301    <class 'str'>
# Name: Case Number, Length: 6302, dtype: object

# %%
# Veo que son strings correspondientes a fechas.
# Voy a quitarles los puntos entre medio. De esta manera voy a poder manejarlos mejor

# %%
df['Case Number'] = df['Case Number'].replace('\.', '', regex=True)

# %%
print(df['Case Number'])
# Out:
# 0       20180625
# 1       20180618
# 2       20180609
# 3       20180608
# 4       20180604
#           ...
# 6297      ND0005
# 6298      ND0004
# 6299      ND0003
# 6300      ND0002
# 6301      ND0001
# Name: Case Number, Length: 6302, dtype: object

# %%
# Veo que estos string IDs no sólo tienen una estructura tipo fecha, sino que también tienen la forma de, por ejemplo, ND0005
# Por ahora eso me da igual, son IDs y cada uno se llama de una manera.
# Parece que la mayoría de esos IDs tienen esas dos "morfologías"

# %% [markdown]
# **COLUMNA 2 - Date**

# %%
# Esta columna representa fechas, se entiende que es la fecha del incidente

# Compruebo el tipo de dato que contiene esta columna

# %%
df['Date'].apply(type)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
#             ...
# 6297    <class 'str'>
# 6298    <class 'str'>
# 6299    <class 'str'>
# 6300    <class 'str'>
# 6301    <class 'str'>
# Name: Date, Length: 6302, dtype: object

# %%
print(df['Date'])
# Out:
# 0       25-Jun-2018
# 1       18-Jun-2018
# 2       09-Jun-2018
# 3       08-Jun-2018
# 4       04-Jun-2018
#            ...
# 6297    Before 1903
# 6298    Before 1903
# 6299      1900-1905
# 6300      1883-1889
# 6301      1845-1853
# Name: Date, Length: 6302, dtype: object

# %%
# Veo que la columna Date contiene datos de fechas pero escritos de manera diferente, muy lioso.

# %%
# Por otro lado, veo que la siguiente columna se llama Year, por lo que voy a ver qué tiene, por si me ayuda para decidir lo que hacer con la de Date.

# %%
print(df['Year'])
# Out:
# 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6302, dtype: float64

# %%
print(df['Year'].value_counts()[0.0])
# Out:
# 125

# %%
# He comprobado que en la columna year hay algunos valores iguales a 0.0. 
# Eso no me da ninguna información, por lo que voy a borrar las filas que tienen ese year 0.0.

# %%
rows_to_drop = df[df['Year'] == 0.0].index
df = df.drop(rows_to_drop)

# %%
df.shape
# Out:
# (6176, 24)

# %%
# Ahora tengo un df de (6176, 24)

# %% [markdown]
# **COLUMNA 4 - Type**

# %%
# Esta columna indica el tipo de ataque: provocado, no provocado, y más tipos que no conozco.
# lo primero que voy a hacer es sacar los valores únicos

# %%
value_counts = df['Type'].value_counts()

print(value_counts)
# Out:
# Unprovoked      4487
# Provoked         567
# Invalid          544
# Sea Disaster     233
# Boating          203
# Boat             135
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
# Voy a agruparlos únicamente en provocados y no provocados
# Voy a pasar las distintas categorías a Unprovoked, y los inválidos los voy a dejar tal y como están.
# Los paso a Unprovoked porque se entiende que en las categorías como Sea Disaster o Boating no se le estaba provocando.

# %%
# Sustituyo los valores de sea disaster, boating, boat, questionable y boatomg y les coloco "Unprovoked"
# para eso creo un diccionario con lo que quiero sustituir, y luego los reemplazo en el df

# %%
diccionario_reemplazar = {'Sea Disaster': 'Unprovoked', 'Boating': 'Unprovoked', 'Boat': 'Unprovoked', 'Questionable': 'Unprovoked', 'Boatomg': 'Unprovoked'}

# %%
# Reemplazar los valores en la columna "Type" utilizando el diccionario de reemplazo
df['Type'] = df['Type'].replace(diccionario_reemplazar)

# %%
print(df['Type'])
# Out:
# 0       Unprovoked
# 1       Unprovoked
# 2          Invalid
# 3       Unprovoked
# 4         Provoked
#            ...
# 6172    Unprovoked
# 6173    Unprovoked
# 6174    Unprovoked
# 6175    Unprovoked
# 6176    Unprovoked
# Name: Type, Length: 6176, dtype: object

# %% [markdown]
# **COLUMNA 5 - Country**

# %%
df['Country']
# Out:
# 0             USA
# 1             USA
# 2             USA
# 3       AUSTRALIA
# 4          MEXICO
#           ...
# 6172       FRANCE
# 6173    VENEZUELA
# 6174       MEXICO
# 6175          NaN
# 6176    AUSTRALIA
# Name: Country, Length: 6176, dtype: object

# %%
# Aquí voy a rellenar los valores nulos por el país que tenga más probabilidad de sufrir ataques.

# Según publicó en el diario 20 min en febrero de 2023, Estados Unidos es el país con más ataques de tiburones en el mundo.

# Por lo tanto, sustituiré los valores nulos por "USA"

# %%
df['Country'].fillna('USA', inplace=True)

df['Country'].head()
# Out:
# 0          usa
# 1          usa
# 2          usa
# 3    australia
# 4       mexico
# Name: Country, dtype: category
# Categories (196, object): ['admiralty islands', 'africa', 'algeria', 'american samoa', ..., 'west indies', 'western samoa', 'yemen', 'USA']

# %% [markdown]
# **COLUMNA 6 - Area**

# %%
df['Area'].value_counts()
# Out:
# Florida                  1029
# New South Wales           484
# Queensland                308
# Hawaii                    295
# California                287
#                          ...
# Island of Kos               1
# Ha'api                      1
# Madeira Islands             1
# Ho Ha Wan Marine Park       1
# Ionian Sea                  1
# Name: Area, Length: 804, dtype: int64

# %%
# 804 valores unicos, o lo que es lo mismo, lugares en los que han ocurrido ataques.

# De los 6mil accidentes aprox, 1029 de ellos son en Florida, "New South Wales" 484, 308 en Queensland, etc...

# Los valores son de tipo int. , por lo que nos viene bien por si tenemos que operar con ellos en algún momento.

# %% [markdown]
# **Special Characters**

# %%
# Me olvidé de hacerlo al principio.
# Voy a borrar los special characters por si acaso me conducen a algún error.

# %%
import re

# Creamos una expresión regular para encontrar los caracteres especiales
regex_special = r'[^\w\s]'

# Aplicamos la expresión regular a todas las celdas del DataFrame y contamos los resultados
count_special = df.applymap(lambda x: bool(re.findall(regex_special, str(x)))).sum().sum()

# Imprimimos el resultado
print("La cantidad de celdas que contienen caracteres especiales es:", count_special)
# Out:
# La cantidad de celdas que contienen caracteres especiales es: 65120

# %%
# Ahora voy a normalizar todos los caracteres especiales a lo largo del dataframe.

import unicodedata

# para ello defino una función para normalizar una cadena
def normalize_string(s):
    return unicodedata.normalize('NFKD', str(s)).encode('ascii', 'ignore').decode('utf-8')

# despues aplico esa función a todo el DataFrame, y el nuevo df se llamara df normalizado
df_normalizado = df.applymap(normalize_string)

# %%
df_normalizado
# Out:
#      Case Number            Date    Year        Type    Country  \
# 0       20180625     25-Jun-2018  2018.0  Unprovoked        USA
# 1       20180618     18-Jun-2018  2018.0  Unprovoked        USA
# 2       20180609     09-Jun-2018  2018.0     Invalid        USA
# 3       20180608     08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4       20180604     04-Jun-2018  2018.0    Provoked     MEXICO
# ...          ...             ...     ...         ...        ...
# 6172    15540000        Ca. 1554  1554.0  Unprovoked     FRANCE
# 6173    15430000        Ca. 1543  1543.0  Unprovoked  VENEZUELA
# 6174    05000000  Circa 500 A.D.   500.0  Unprovoked     MEXICO
# 6175    00770000        77  A.D.    77.0  Unprovoked        nan
# 6176    00050000      Ca. 5 A.D.     5.0  Unprovoked  AUSTRALIA
#
#                              Area                        Location  \
# 0                      California     Oceanside, San Diego County
# ...

# %%
count_special_normalizado = df_normalizado.applymap(lambda x: bool(re.findall(regex_special, str(x)))).sum().sum()
print("La cantidad de caracteres especiales en el DataFrame normalizado es:", count_special_normalizado)
# Out:
# La cantidad de caracteres especiales en el DataFrame normalizado es: 65063

# %%
# Antes había 65120 caracteres especiales, pero tras correr la función normalize a lo largo del df, ahora se han reducido a 65063

# %%
# Ahora voy a borrar todos los caracteres especiales del df

# %%
import re

regex_special = r'[^\w\s]'
df_clean = df.replace(regex_special, '', regex=True)

# %%
# compruebo que no hay caracteres especiales

import re

regex_special = r'[^\w\s]'
count_special = df_clean.applymap(lambda x: bool(re.findall(regex_special, str(x)))).sum().sum()
print("La cantidad de caracteres especiales en el DataFrame limpio es:", count_special)
# Out:
# La cantidad de caracteres especiales en el DataFrame limpio es: 12350

# %%
# Se han eliminado muchos, aunque todavía quedan. Los voy a dejar así por ahora.

# %% [markdown]
# **Voy a cambiar los IDs de la primera columna por un indice sencillo**

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0    20180625  25-Jun-2018  2018.0  Unprovoked        USA       California
# 1    20180618  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    20180609  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    20180608  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    20180604  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df.shape
# Out:
# (6176, 24)

# %%
# Generar una secuencia de números del 1 al 6176
n_filas = len(df)
numeros = range(1, n_filas+1)

# Asignar los números a la columna "Case Number"
df['Case Number'] = numeros

# %%
df.head()
# Out:
#    Case Number         Date    Year        Type    Country             Area  \
# 0            1  25-Jun-2018  2018.0  Unprovoked        USA       California
# 1            2  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2            3  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3            4  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4            5  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# Hecho. De esta manera tengo los case numbers ordenados del 1 al 6176 , y es más fácil usarlos.

# %% [markdown]
# **Columa 7 - Location**

# %%
# Voy a quitar espacios en en blanco innecesarios

# %%
df['Location'] = df['Location'].str.strip()

# %%
df['Location']
# Out:
# 0          Oceanside, San Diego County
# 1       St. Simon Island, Glynn County
# 2                         Habush, Oahu
# 3                   Arrawarra Headland
# 4                             La Ticla
#                      ...
# 6172                               NaN
# 6173                               NaN
# 6174                               NaN
# 6175                               NaN
# 6176                             Bondi
# Name: Location, Length: 6176, dtype: object

# %%
# Sé que algunas localizaciones son más concretas que otras, pero no voy a estandarizarlas y ponerlas todas con la misma estructura.
# Creo que tener más información en algunas celdas no "ensucia" el dataframe.

# %% [markdown]
# **Columa 8 - Activity**

# %%
df['Activity'].tolist()
# Out:
# ['Paddling',
#  'Standing',
#  'Surfing',
#  'Surfing',
#  'Free diving',
#  'Kite surfing',
#  'Swimming',
#  'Fishing',
#  'Walking',
#  'Standing',
#  'Feeding sharks',
#  'Boogie boarding',
#  'Swimming',
#  'Fishing',
#  'Feeding sharks',
#  'Surfing',
#  'Surfing',
#  'Swimming',
#  'Scuba diving',
#  'Surfing',
#  'Surfing',
#  'Surfing',
#  'Surfing',
#  'Fishing',
#  'Paddle-skiing',
#  'Body boarding',
#  'Swimming',
#  'Swimming',
#  'Surfing',
#  'Surfing',
#  'Surfing',
#  'Fishing',
#  'Windsurfing',
#  'Swimming',
#  'Surfing',
#  'Stand-Up Paddleboarding',
#  'Wading',
#  'Swimming',
#  'Surfing',
#  'Scuba Diving',
#  'Swimming',
#  'Kayak fishing for sharks',
#  'Walking',
#  'Swimming',
#  'Cleaning fish',
#  'Snorkeling',
#  'Spearfishing',
#  nan,
#  'Spearfishing',
#  'Diving',
#  'Free diving',
#  'Surfing',
#  'Surfing',
#  'Surfing',
#  'Surfing',
#  'Fishing / Wading',
#  'Snorkeling',
#  'Scuba Diving',
#  'Scuba diving',
#  '2 boats capsized',
# ...

# %%
df['Activity'].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ..., 'Went overboard',
#        'Ship lay at anchor & man was working on its rudder',
#        'Man fell overboard from ship. Those on board threw a rope to him with a wooden block & were pulling him to the ship'],
#       dtype=object)

# %%
# Veo que hay descripciones de la actividad en cuestión de varias palabras, cuando la mayoría están descritas con una palabra
# ejemplo : Swimming , Surfing , Fishing

# Voy a filtrar las actividades que tengan más de dos palabras

# %%
lista = df[df['Activity'].str.split().str.len() >= 2]['Activity'].tolist()

lista
# Out:
# ['Free diving',
#  'Kite surfing',
#  'Feeding sharks',
#  'Boogie boarding',
#  'Feeding sharks',
#  'Scuba diving',
#  'Body boarding',
#  'Stand-Up Paddleboarding',
#  'Scuba Diving',
#  'Kayak fishing for sharks',
#  'Cleaning fish',
#  'Free diving',
#  'Fishing / Wading',
#  'Scuba Diving',
#  'Scuba diving',
#  '2 boats capsized',
#  'Night bathing',
#  'Stand-Up Paddleboarding',
#  'Kayaking / Fishing',
#  'Scuba Diving',
#  'Body surfing',
#  'Scuba Diving',
#  'Swimming, poaching abalone',
#  'Kayaking / Fishing',
#  'Body boarding',
#  'Feeding sharks',
#  'Body boarding',
#  'Touching a shark',
#  'Feeding sharks',
#  'Attempting to lasso a shark',
#  'Body boarding',
#  'Body boarding',
#  'Photo shoot',
#  'Scuba Diving',
#  'Paddle boarding',
#  'Body boarding',
#  'Washing hands',
#  'Body boarding',
#  'Grabbing shark for a selfie',
#  'Kayak fishing',
#  'Tagging sharks',
#  'Scuba Diving',
#  'Scuba Diving',
#  'Surf skiing ',
#  'Free diving',
#  'Surf fishing',
# ...

# %%
# convierto todas las cadenas a minúsculas

import re

df['Activity'] = df['Activity'].str.lower()

# %%
df['Activity']
# Out:
# 0            paddling
# 1            standing
# 2             surfing
# 3             surfing
# 4         free diving
#             ...
# 6172              NaN
# 6173     pearl diving
# 6174              NaN
# 6175    sponge diving
# 6176              NaN
# Name: Activity, Length: 6176, dtype: object

# %%
num_elementos = len([elemento for elemento in df['Activity'].dropna() if len(elemento.split()) >= 2])

num_elementos
# Out:
# 2113

# %%
df.shape # he comprobado si por si acaso me había sobrescrito las filas del df, pero no
# Out:
# (6176, 24)

# %%
df['Activity'] = df['Activity'].fillna('none')

# %%
type(df['Activity'])
# Out:
# pandas.core.series.Series

# %%
df['Activity'] = df['Activity'].astype(str)

# %%
print(df['Activity'].dtype)
# Out:
# object

# %%
lista_surfing_final = df[df['Activity'].str.lower().str.split().apply(lambda x: len(x) >= 2 and 'surfing' in x)]['Activity'].tolist()

lista_surfing_final
# Out:
# ['kite surfing',
#  'body surfing',
#  'kite surfing',
#  'kite surfing',
#  'kite surfing',
#  'body surfing',
#  'kite surfing',
#  'surfing & filming dolphins',
#  'body surfing or boogie boarding',
#  'body surfing',
#  'body surfing',
#  'body surfing',
#  'kite surfing',
#  'kite surfing',
#  'body surfing',
#  'body surfing',
#  'kite surfing',
#  'kite surfing',
#  'kite surfing',
#  'body surfing',
#  'kite surfing',
#  'swimming or surfing',
#  'body surfing',
#  'body surfing',
#  'body surfing',
#  'walking out of the water after surfing',
#  'walking out of the water after surfing',
#  'walking out of the water after surfing',
#  'swimming / body surfing',
#  'night surfing',
#  'standing / surfing',
#  'treading water/ surfing',
#  'body surfing',
#  'standing / surfing',
#  'tandem surfing',
#  'surfing amid a shoal of sharks',
#  'swimming or surfing',
#  'boogie boarding or surfing',
#  'body surfing',
#  'body surfing',
#  'standing / surfing',
# ...

# %%
lista_surfing_definitiva = ['surfing' if 'surfing' in actividad.lower() else actividad for actividad in lista_surfing_final]

lista_surfing_definitiva
# Out:
# ['surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
# ...

# %%
df['Activity'] = ['surfing' if 'surfing' in actividad.lower() else actividad for actividad in df['Activity']]

# %%
surfing_activities = list(filter(lambda x: 'surfing' in x.lower(), df['Activity']))

# %%
surfing_activities
# Out:
# ['surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
#  'surfing',
# ...

# %%
# Lo que he hecho ha sido reemplazar los elementos que tenían la palabra surfing y dejarlos en "surfing" simplemente
# después he comprobado que se ha sobrescrito mi df.

# Ahora voy a hacer lo mismo con las que contengan Fish ---> Fishing

# %%
df['Activity'] = df['Activity'].str.replace('fish', 'fishing', case=False)

df['Activity'] = df['Activity'].str.replace('fishinginging', 'fishing', case=False)

df['Activity'].value_counts()

# Y ahora lo mismo con "Swim...etc" ---> Swimming


df['Activity'] = df['Activity'].str.replace('swim', 'swimming', case=False)

df['Activity'] = df['Activity'].str.replace('swimmingming', 'swimming', case=False)

df['Activity'].value_counts()
# Out:
# fishinging                                                                                                             1198
# surfing                                                                                                                1124
# swimming                                                                                                                847
# none                                                                                                                    520
# bathing                                                                                                                 157
#                                                                                                                        ...
# lobster diving using scuba                                                                                                1
# ...

# %% [markdown]
# **Columna 9 - Name**

# %%
df['Name']
# Out:
# 0                 Julie Wolfe
# 1             Adyson McNeely
# 2                 John Denges
# 3                        male
# 4              Gustavo Ramos
#                 ...
# 6172    males (wearing armor)
# 6173             Indian slave
# 6174                     male
# 6175                    males
# 6176                     male
# Name: Name, Length: 6176, dtype: object

# %%
# veo que en la columna de nombres, aparecen muchas veces las palabras male o female, y no deberían estar ahí.

# vamos a filtrarlas y a cambiarlas por "unknown name"

# %%
# Filtrar la columna "Name"
filtro = df['Name'].str.contains('male|female', case=False)

filtro
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 6172     True
# 6173    False
# 6174     True
# 6175     True
# 6176     True
# Name: Name, Length: 6176, dtype: object

# %%
# Convertir la columna filtrada en una lista
name_list = df.loc[filtro, 'Name'].tolist()

# Imprimir la lista
print(name_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/75/q598wy0x5rq2j183ndtczjlm0000gn/T/ipykernel_90093/4239044145.py in <module>
#       1 # Convertir la columna filtrada en una lista
# ----> 2 name_list = df.loc[filtro, 'Name'].tolist()
#       3
#       4 # Imprimir la lista
#       5 print(name_list)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1138         with suppress(IndexingError):
# ...

# %%
# me da error creo que porque hay algunos valores nulos

# %%
# Filtrar la columna "Name"
filtro = df['Name'].str.contains('male|female', case=False).fillna(False)

# Convertir la columna filtrada en una lista
name_list = df.loc[filtro, 'Name'].tolist()

# Imprimir la lista
print(name_list)
# Out:
# ['male', 'male', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'female x 2', 'female', 'female', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'female', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'female', 'male', 'male', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'male', 'male', '
# ...

# %%
# de esta manera corregimos el error ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# ahora vamos a sustituir todos estos valores por "unknown name"

# %%
df.loc[df['Name'].isin(name_list), 'Name'] = 'unknown name'

# %%
df['Name']
# Out:
# 0           Julie Wolfe
# 1       Adyson McNeely
# 2           John Denges
# 3          unknown name
# 4        Gustavo Ramos
#              ...
# 6172       unknown name
# 6173       Indian slave
# 6174       unknown name
# 6175       unknown name
# 6176       unknown name
# Name: Name, Length: 6176, dtype: object

# %%
# Ahora tenemos una columna que contiene nombres, y los que estaban mal ahora muestran 'unknown name'

# %% [markdown]
# **Columna 10 - Sex**

# %%
sex_list = df['Sex'].tolist()

# Imprimir la lista
print(sex_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Veo que hay algunos nombres de columnas que tienen espacios en sus laterales. Voy a corregirlos

# %%
# Creo un diccionario con los nuevos nombres de las columnas usando un bucle for
new_columns = {col: col.strip() for col in df.columns}

# Renombrar las columnas del DataFrame
df = df.rename(columns=new_columns)

# %%
df.columns # ahora está corregido
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sex_list = df['Sex'].tolist()

print(sex_list)
# Out:
# ['F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', nan, 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'F', nan, 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', nan, 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', nan, 'F', 'M', 'F', 'M', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'F', 'F', 'F', 'M', nan, 'F', 'M', 'M', 'F', 'M', 'F', 'F', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'F', 'M', nan, 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M
# ...

# %%
# Veo que hay varios nan ("Not a Number"). 
# Podría revisar los nombres y determinar si es male o female, pero no soy nadie para definir el género de otra persona.

# %% [markdown]
# **Columna 11 - Species**

# %%
df['Species'].value_counts()
# Out:
# White shark                                           162
# Shark involvement prior to death was not confirmed    105
# Invalid                                               101
# Shark involvement not confirmed                        88
# Tiger shark                                            70
#                                                      ...
# A 2' shark was seen in the area by witnesses            1
# White shark, 3.5 m [11.5']  male                        1
# 60 cm to 90 cm [2' to 3'] shark                         1
# 100-kg [221-lb] dead blue shark                         1
# Possibly white sharks                                   1
# Name: Species, Length: 1534, dtype: int64

# %%
# voy a reemplazar los valores en los que pone 'Shark involvement prior to death was not confirmed' por 'Shark involvement not confirmed'
df['Species'] = df['Species'].replace('Shark involvement prior to death was not confirmed', 'Shark involvement not confirmed')

df['Species'].value_counts()
# Out:
# Shark involvement not confirmed                 193
# White shark                                     162
# Invalid                                         101
# Tiger shark                                      70
# Shark involvement prior to death unconfirmed     68
#                                                ...
# A 2' shark was seen in the area by witnesses      1
# White shark, 3.5 m [11.5']  male                  1
# 60 cm to 90 cm [2' to 3'] shark                   1
# 100-kg [221-lb] dead blue shark                   1
# Possibly white sharks                             1
# Name: Species, Length: 1533, dtype: int64

# %%
df['Species'] = df['Species'].replace('Shark involvement prior to death unconfirmed', 'Shark involvement not confirmed')

df['Species'].value_counts()
# Out:
# Shark involvement not confirmed                     261
# White shark                                         162
# Invalid                                             101
# Tiger shark                                          70
# Bull shark                                           48
#                                                    ...
# 4.5' to 5' shark                                      1
# Caribbean reef shark, 1.2 m to 1.5 m [4' to 5']       1
# Dusky shark, 12'                                      1
# White shark, 5 m to 6 m [16.5' to 20']                1
# Possibly white sharks                                 1
# Name: Species, Length: 1532, dtype: int64

# %%
# También voy a sustituir los elementos que ponen "White sharks (seguido de algo)" por simplemente "White shark"

df['Species'].fillna(value='0', inplace=True)

# Tengo que rellenar los nulos con 0 para que me deje hacer la conversión

df.loc[df['Species'].str.contains('white', case=False), 'Species'] = 'White Shark'

df['Species'].value_counts()
# Out:
# 0                                                                                                                                    2713
# White Shark                                                                                                                           664
# Shark involvement not confirmed                                                                                                       256
# Invalid                                                                                                                               101
# Tiger shark                                                                                                                            70
#                                                                                                                                      ...
# 2' to 3.5' shark                                                                                                                        1
# ...

# %%
# Ahora sustituiré todos los demás por "Undetermined shark"

df.loc[~df['Species'].isin(['Shark involvement not confirmed', 'White shark', 'Invalid', 'Tiger shark', 'Bull shark']), 'Species'] = 'Undetermined shark'

df['Species'].value_counts()
# Out:
# Undetermined shark                 5655
# Shark involvement not confirmed     256
# Invalid                             101
# Tiger shark                          70
# Bull shark                           48
# Name: Species, dtype: int64

# %% [markdown]
# **Columna 12 - Investigator or Source**

# %%
df['Investigator or Source'].value_counts()
# Out:
# C. Moore, GSAF                     102
# C. Creswell, GSAF                   91
# S. Petersohn, GSAF                  82
# R. Collier                          55
# R. Collier, GSAF                    48
#                                   ...
# Jupiter Courier, 11/20/1996          1
# R. Collier, p.158                    1
# The Advertiser, 12/30/1996, p.3      1
# The Advertiser, 1/3/1997, p.7        1
# Waverly Library                      1
# Name: Investigator or Source, Length: 4877, dtype: int64

# %%
# Veo que hay elementos con valores numéricos. Voy a borrar esos valores numéricos

import re

df['Investigator or Source'] = df['Investigator or Source'].replace(to_replace=r'\d+', value='', regex=True)

# %%
# Compruebo que se han borrado.

print(df['Investigator or Source'].unique())
# Out:
# ['R. Collier, GSAF' 'K.McMurray, TrackingSharks.com' 'B. Myatt, GSAF' ...
#  'J. Castro' 'Perils mentioned by Pliny the Elder ( A.D. to  A.D.)'
#  'Waverly Library']

# %% [markdown]
# **Columna 14 - href formula**

# %%
# Esto es una columna con enlaces

# Voy a leerlos por si me dan alguna información interesante acerca del dataframe

# %%
df['href formula'] # De las que aparecen aquí, ningún enlace funciona
# Out:
# 0       http://sharkattackfile.net/spreadsheets/pdf_di...
# 1       http://sharkattackfile.net/spreadsheets/pdf_di...
# 2       http://sharkattackfile.net/spreadsheets/pdf_di...
# 3       http://sharkattackfile.net/spreadsheets/pdf_di...
# 4       http://sharkattackfile.net/spreadsheets/pdf_di...
#                               ...
# 6172    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6173    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6174    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6175    http://sharkattackfile.net/spreadsheets/pdf_di...
# 6176    http://sharkattackfile.net/spreadsheets/pdf_di...
# Name: href formula, Length: 6176, dtype: object

# %%
df['href formula'].value_counts()
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/1929.03.04.a-b.Roads-Aldridge.pdf      2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1931.09.21.a-b-Holaday-Barrows.pdf     2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1907.10.16.R-HongKong.pdf              2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1923.00.00.a-NJ fisherman.pdf          2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1921.11.27.a-b-Jack.pdf                2
#                                                                                             ..
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.06.02-Alcorn.pdf                  1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.06.09.a-Anderson.pdf              1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.06.09.b-Watley.pdf                1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.06.10-Alexander.pdf               1
# ...

# %%
# Leo los enlaces por si contienen información útil acerca de los ataques

# %% [markdown]
# **Columna 15 - href**

# %%
df['href'].value_counts()
# Out:
# http://sharkattackfile.net/spreadsheets/pdf_directory/w014.01.25-Grant.pdf                   4
# http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.02.b-Vandenberg.pdf            3
# http://sharkattackfile.net/spreadsheets/pdf_directory/1907.10.16.R-HongKong.pdf              2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1923.00.00.a-NJ fisherman.pdf          2
# http://sharkattackfile.net/spreadsheets/pdf_directory/1921.11.27.a-b-Jack.pdf                2
#                                                                                             ..
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.04.09-boy.pdf                     1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.04.14-Metz.pdf                    1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.05.07.a-diver.pdf                 1
# http://sharkattackfile.net/spreadsheets/pdf_directory/2000.05.07.b-Adam.pdf                  1
# ...

# %%
# He comprobado que las columnas Href formula y Href no son iguales, ya que contienen algunos enlaces diferentes.
# Por ahora las voy a dejar así

# %% [markdown]
# **Columna 16 y 17 - Case Number.1 y Case Number.2**

# %%
igualdad = df['Case Number.1'].equals(df['Case Number.2'])

igualdad
# Out:
# False

# %%
diferentes = df.loc[df['Case Number.1'] != df['Case Number.2']]
display(diferentes)
# Out:
#       Case Number                                  Date    Year        Type  \
# 34             35                           03-Apr-2018  2018.0  Unprovoked
# 117           118                           20-Jul-2017  2017.0  Unprovoked
# 144           144                           05-May-2017  2017.0  Unprovoked
# 217           217                           16-Sep-2016  2016.0  Unprovoked
# 314           314                           24-Jan-2016  2016.0  Unprovoked
# 334           334                           07-Nov-2015  2015.0     Invalid
# 339           339                           28-Oct-2015  2015.0  Unprovoked
# 560           560                           04-May-2014  2014.0  Unprovoked
# 3522         3522                           05-Jul-1967  1967.0  Unprovoked
# 3795         3795                           30-Aug-1962  1962.0  Unprovoked
# 3880         3880                  Reported 06-Sep-1961  1961.0    Provoked
# ...

# %%
# Aquí pasa lo mismo, parecen columnas iguales, pero tienen algunos elementos diferentes.
# Por ahora la voy a dejar así.

# %% [markdown]
# **Columna 18 - original order**

# %%
df['original order'].value_counts()
# Out:
# 569.0     2
# 6303.0    1
# 2188.0    1
# 2179.0    1
# 2180.0    1
#          ..
# 4246.0    1
# 4247.0    1
# 4248.0    1
# 4249.0    1
# 127.0     1
# Name: original order, Length: 6175, dtype: int64

# %%
# Esta columna contiene elementos de tipo integer, casi todos diferentes unos de otros.
# No sé lo que significan. Tengo la sensación de que puede proporcionar información sobre la forma en que se recopilaron los datos y cómo se pueden interpretar

# %% [markdown]
# **Columnas 22 y 23 - Unnamed: 22 y Unnamed: 23**

# %%
df['Unnamed: 22']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 6172    NaN
# 6173    NaN
# 6174    NaN
# 6175    NaN
# 6176    NaN
# Name: Unnamed: 22, Length: 6176, dtype: object

# %%
if df['Unnamed: 22'].equals(df['Unnamed: 23']):
    print("Las columnas son iguales")
else:
    print("Las columnas son diferentes")
# Out:
# Las columnas son diferentes

# %%
# Veo que son diferentes, pero como la mayoría de valores son Nan, voy a cambiarlos por 0.

# %%
df['Unnamed: 22'] = 0
df['Unnamed: 23'] = 0

# %%
df['Unnamed: 22']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6172    0
# 6173    0
# 6174    0
# 6175    0
# 6176    0
# Name: Unnamed: 22, Length: 6176, dtype: int64

# %%
# Comprobado que se han sustituido por 0.

# %% [markdown]
# **REVISIÓN GENERAL DEL DATAFRAME**

# %%
# Ahora mismo el dataframe quedaría así:

# %%
df.head()
# Out:
#    Case Number         Date    Year        Type    Country             Area  \
# 0            1  25-Jun-2018  2018.0  Unprovoked        USA       California
# 1            2  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2            3  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3            4  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4            5  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  ...  \
# 0     Oceanside, San Diego County     paddling      Julie Wolfe   F  ...
# 1  St. Simon Island, Glynn County     standing  Adyson McNeely    F  ...
# 2                    Habush, Oahu      surfing      John Denges   M  ...
# 3              Arrawarra Headland      surfing     unknown name   M  ...
# 4                        La Ticla  free diving   Gustavo Ramos    M  ...
#
# ...

# %%
# Limpio la columna de países de espacios y los cambio a minusculas
df['Country'] = df['Country'].str.lower().str.strip()

# Elimino filas con valores nulos
df = df.dropna(subset=['Country'])

# Convertir la columna en tipo de datos categóricos
df['Country'] = df['Country'].astype('category')

# Ordeno el DataFrame por la columna "Pais"
df_ordenado = df.sort_values(by='Country')

# Agrupo las filas por país
df_agrupado = df_ordenado.groupby('Country')
# Out:
# /var/folders/75/q598wy0x5rq2j183ndtczjlm0000gn/T/ipykernel_90093/785353727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'] = df['Country'].str.lower().str.strip()

# %%
df.head()
# Out:
#    Case Number         Date    Year        Type    Country             Area  \
# 0            1  25-Jun-2018  2018.0  Unprovoked        usa       California
# 1            2  18-Jun-2018  2018.0  Unprovoked        usa          Georgia
# 2            3  09-Jun-2018  2018.0     Invalid        usa           Hawaii
# 3            4  08-Jun-2018  2018.0  Unprovoked  australia  New South Wales
# 4            5  04-Jun-2018  2018.0    Provoked     mexico           Colima
#
#                          Location     Activity             Name Sex  ...  \
# 0     Oceanside, San Diego County     paddling      Julie Wolfe   F  ...
# 1  St. Simon Island, Glynn County     standing  Adyson McNeely    F  ...
# 2                    Habush, Oahu      surfing      John Denges   M  ...
# 3              Arrawarra Headland      surfing     unknown name   M  ...
# 4                        La Ticla  free diving   Gustavo Ramos    M  ...
#
# ...

# %%
# No consigo agruparlas por paises.

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# **Columna 11 - Injury**

# %%
df['Injury'].value_counts()
# Out:
# FATAL                                                            748
# Survived                                                          93
# Foot bitten                                                       83
# No injury                                                         81
# Leg bitten                                                        71
#                                                                 ...
# Ear lacerated, cuts on scalp, back, arm & shoulder                 1
# Right ankle & heel  lacerated                                      1
# Right thigh & buttock bitten                                       1
# Five cuts on his heel                                              1
# Aboriginal rock carving depicts man being attacked by a shark      1
# Name: Injury, Length: 3671, dtype: int64

# %%
# Voy a reducirlos a dos categorias: Survived y not survived

# %%
df['Injury'] = df['Injury'].replace('FATAL', 'Not Survived')
df['Injury'].value_counts()
# Out:
# Not Survived                                                     748
# Survived                                                          93
# Foot bitten                                                       83
# No injury                                                         81
# Leg bitten                                                        71
#                                                                 ...
# Ear lacerated, cuts on scalp, back, arm & shoulder                 1
# Right ankle & heel  lacerated                                      1
# Right thigh & buttock bitten                                       1
# Five cuts on his heel                                              1
# Aboriginal rock carving depicts man being attacked by a shark      1
# Name: Injury, Length: 3671, dtype: int64

# %%
mask = df['Injury'] != 'Not Survived'
df['Injury'] = np.where(mask, 'Survived', 'Not Survived')
df['Injury'].value_counts()
# Out:
# Survived        5382
# Not Survived     748
# Name: Injury, dtype: int64

# %%
# De esta manera lo hacemos más sencillo, ya que teníamos mucha información diferente, y que no aclaraba exactamente si había sobrevivido o no.
# También le cambiaremos el nombre a la columna, y le pondremos Survived or Not

# %%
df = df.rename(columns={'Injury': 'Survived or Not'})

# %%
df['Survived or Not']
# Out:
# 0           Survived
# 1           Survived
# 2           Survived
# 3           Survived
# 4           Survived
#             ...
# 6170        Survived
# 6172        Survived
# 6173    Not Survived
# 6174        Survived
# 6176        Survived
# Name: Survived or Not, Length: 6130, dtype: object

# %%
# comprobado que se ha cambiado el nombre de la columna

# %% [markdown]
# **Columna 12 - Fatal Y/N**

# %%
df['Fatal (Y/N)']
# Out:
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
#          ...
# 6170          Y
# 6172    UNKNOWN
# 6173          Y
# 6174          N
# 6176          N
# Name: Fatal (Y/N), Length: 6130, dtype: object

# %%
# Como ya he añadido la fatalidad de los incidentes en la columna anterior, esta la voy a convertir en ceros.

# %%
df.loc[:, 'Fatal (Y/N)'] = 0

# %%
df['Fatal (Y/N)']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6170    0
# 6172    0
# 6173    0
# 6174    0
# 6176    0
# Name: Fatal (Y/N), Length: 6130, dtype: int64

# %% [markdown]
# **Columna 13 - Time**

# %%
df['Time'].value_counts()
# Out:
# Afternoon      182
# 11h00          127
# Morning        120
# 12h00          109
# 15h00          108
#               ...
# 00h30            1
# 14h37            1
# 10h07            1
# 13h53            1
# 19h00-20h00      1
# Name: Time, Length: 365, dtype: int64

# %%
df['Time'].tolist()
# Out:
# ['18h00',
#  '14h00  -15h00',
#  '07h45',
#  nan,
#  nan,
#  nan,
#  'Late afternoon',
#  nan,
#  '17h00',
#  '14h00',
#  'Morning',
#  nan,
#  '15h00',
#  '08h15',
#  nan,
#  '11h00',
#  '10h30',
#  nan,
#  '10h40',
#  '16h50',
#  '07h00',
#  '09h30',
#  'Afternoon',
#  '21h50',
#  '09h40',
#  nan,
#  nan,
#  nan,
#  nan,
#  '08h00',
#  '09h30',
#  nan,
#  '17h00',
#  '18h00',
#  '15h00',
#  '09h30',
#  '17h35',
#  '15h30',
#  '07h30',
#  nan,
#  '19h00, Dusk',
#  'Night',
#  '16h00',
#  '18h00',
#  nan,
#  nan,
#  nan,
#  '08h00',
#  '15h30',
#  '15h01',
#  nan,
#  'Late afternoon',
#  nan,
#  '18h00',
#  '12h00',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '13h45',
#  'Late afternoon',
#  '16h00',
#  '23h30',
#  nan,
#  '09h00',
#  '15h00',
#  'Afternoon',
#  '17h00',
#  '08h00',
#  'Afternoon',
#  '09h00',
#  '14h30',
#  '18h30',
#  '12h30',
#  nan,
#  'Morning',
#  '18h00',
#  '15h30',
#  '14h00',
#  'Morning',
#  nan,
#  '16h30',
#  'Afternoon',
#  'Night',
#  nan,
#  '18h45',
# ...

# %%
# Limpio valores nulos y caracteres especiales
df['Time'] = df['Time'].fillna('').apply(lambda x: ''.join(e for e in x if e.isalnum()))

# %%
df['Time'].tolist()
# Out:
# ['18h00',
#  '14h0015h00',
#  '07h45',
#  '',
#  '',
#  '',
#  'Lateafternoon',
#  '',
#  '17h00',
#  '14h00',
#  'Morning',
#  '',
#  '15h00',
#  '08h15',
#  '',
#  '11h00',
#  '10h30',
#  '',
#  '10h40',
#  '16h50',
#  '07h00',
#  '09h30',
#  'Afternoon',
#  '21h50',
#  '09h40',
#  '',
#  '',
#  '',
#  '',
#  '08h00',
#  '09h30',
#  '',
#  '17h00',
#  '18h00',
#  '15h00',
#  '09h30',
#  '17h35',
#  '15h30',
#  '07h30',
#  '',
#  '19h00Dusk',
#  'Night',
#  '16h00',
#  '18h00',
#  '',
#  '',
#  '',
#  '08h00',
#  '15h30',
#  '15h01',
#  '',
#  'Lateafternoon',
#  '',
#  '18h00',
#  '12h00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '13h45',
#  'Lateafternoon',
#  '16h00',
#  '23h30',
#  '',
#  '09h00',
#  '15h00',
#  'Afternoon',
#  '17h00',
#  '08h00',
#  'Afternoon',
#  '09h00',
#  '14h30',
#  '18h30',
#  '12h30',
#  '',
#  'Morning',
#  '18h00',
#  '15h30',
#  '14h00',
#  'Morning',
#  '',
#  '16h30',
#  'Afternoon',
#  'Night',
#  '',
#  '18h45',
#  '15h00',
#  '06h00',
#  '',
# ...

# %%
df.head()
# Out:
#    Case Number         Date    Year        Type    Country             Area  \
# 0            1  25-Jun-2018  2018.0  Unprovoked        usa       California
# 1            2  18-Jun-2018  2018.0  Unprovoked        usa          Georgia
# 2            3  09-Jun-2018  2018.0     Invalid        usa           Hawaii
# 3            4  08-Jun-2018  2018.0  Unprovoked  australia  New South Wales
# 4            5  04-Jun-2018  2018.0    Provoked     mexico           Colima
#
#                          Location     Activity             Name Sex  ...  \
# 0     Oceanside, San Diego County     paddling      Julie Wolfe   F  ...
# 1  St. Simon Island, Glynn County     standing  Adyson McNeely    F  ...
# 2                    Habush, Oahu      surfing      John Denges   M  ...
# 3              Arrawarra Headland      surfing     unknown name   M  ...
# 4                        La Ticla  free diving   Gustavo Ramos    M  ...
#
# ...

# %% [markdown]
# ## **CONCLUSION** ##

# %%
# Hemos llevado a cabo los siguientes procedimientos:

# Elimar las filas que no contenían información relevante para el estudio.
# Reemplazar los valores faltantes con información estimada.
# Eliminar registros duplicados.
# Verificar los tipos de datos de cada columna y corregir aquellos que no correspondían.
# Suprimir los caracteres especiales y normalizar los valores de las columnas.
# Realizar cambios de tipos de datos.
# Cambiar los nombres de algunas columnas para facilitar su comprensión.
# Convertir algunas columnas irrelevantes o incompletas en 0.
# Sustituir ciertos valores nulos por elementos comunes según la probabilidad.

# %%
# Ahora exportamos a CSV , e incluimos index = False , para que no se escriba la columna del índice.

df.to_csv('your_code_final.csv', index=False)
